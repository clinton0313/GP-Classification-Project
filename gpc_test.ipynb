# %%
from gpc import GPC
from utils import matern_kernel
import numpy as np

# %%
X = np.random.multivariate_normal(1, 1, 100)
Y = np.random.randint(0, 2, 100)

gpc = GPC(matern_kernel, [1, 1, 1.5], ["variance", "length", "nu"])

gpc.fit(X, Y, verbose=1)
# Out:
# variance: 1.0 length: 1.05 nu: 1.5
# variance: 1.0 length: 1.05 nu: 1.5
# variance: 1.0 length: 1.05 nu: 1.5
# variance: 1.0 length: 1.05 nu: 1.5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_896887/3081000000.py in <module>
#       4 gpc = GPC(matern_kernel, [1, 1, 1.5], ["variance", "length", "nu"])
#       5
# ----> 6 gpc.fit(X, Y, verbose=1)
#
# ~/Documents/probabilistic_inference/project/gpc.py in fit(self, X, y, maxiter, tol, verbose, **kwargs)
#     128                     print(parameters)
#     129
# --> 130         res = minimize(
#     131             nll,
#     132             self.hyperparameters,
#
# ~/.virtualenvs/DS/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     609
#     610     if meth == 'nelder-mead':
# ...
